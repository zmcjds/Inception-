# %%
@keras.utils.register_keras_serializable()
class Inception(tf.keras.layers.Layer):
    def __init__(self,fliter_list,**kwargs):
        super(Inception,self).__init__(**kwargs)
        self.fliter_list=fliter_list
        self.C1=layers.Conv2D(fliter_list[0],kernel_size=(1,1),padding="same",activation="relu")
        self.C2_1=layers.Conv2D(fliter_list[1],kernel_size=(1,1),padding="same",activation="relu")
        self.C2=layers.Conv2D(fliter_list[2],kernel_size=(3,3),padding="same",activation="relu")
        self.C3_1=layers.Conv2D(fliter_list[3],kernel_size=(1,1),padding="same",activation="relu")
        self.C3=layers.Conv2D(fliter_list[4],kernel_size=(5,5),padding="same",activation="relu")
        self.S4_1=layers.MaxPool2D(pool_size=3,strides=1,padding="same")
        self.C4=layers.Conv2D(fliter_list[5],kernel_size=(1,1),padding="same",activation="relu")
    def call(self,inputs):
        conv1=self.C1(inputs)
        
        conv2_1=self.C2_1(inputs)
        conv2=self.C2(conv2_1)
        
        conv3_1=self.C3_1(inputs)
        conv3=self.C3(conv3_1)
        
        pool4_1=self.S4_1(inputs)
        conv4=self.C4(pool4_1)
        
        return layers.Concatenate(axis=-1)([conv1,conv2,conv3,conv4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 @keras.utils.register_keras_serializable()
#       2 class Inception(tf.keras.layers.Layer):
#       3     def __init__(self,fliter_list,**kwargs):
#       4         super(Inception,self).__init__(**kwargs)
#
# NameError: name 'keras' is not defined

# %%
@keras.utils.register_keras_serializable()
class Inception_v3_1(tf.keras.layers.Layer):
    def __init__(self,fliter_list,**kwargs):
        super(Inception_v3_1,self).__init__(**kwargs)
        self.fliter_list=fliter_list
        self.C1=layers.Conv2D(fliter_list[0],kernel_size=(1,1),padding="same",activation="relu")
        
        self.C2_1=layers.Conv2D(fliter_list[1],kernel_size=(1,1),padding="same",activation="relu")
        self.C2=layers.Conv2D(fliter_list[2],kernel_size=(3,3),padding="same",activation="relu")
        
        self.C3_1=layers.Conv2D(fliter_list[3],kernel_size=(1,1),padding="same",activation="relu")
        self.C3_2=layers.Conv2D(fliter_list[4],kernel_size=(3,3),padding="same",activation="relu")
        self.C3=layers.Conv2D(fliter_list[5],kernel_size=(3,3),padding="same",activation="relu")
        
        self.S4_1=layers.MaxPool2D(pool_size=3,strides=1,padding="same")
        self.C4=layers.Conv2D(fliter_list[6],kernel_size=(1,1),padding="same",activation="relu")
        
    def call(self,inputs):
        conv1=self.C1(inputs)
        
        conv2_1=self.C2_1(inputs)
        conv2=self.C2(conv2_1)
        
        conv3_1=self.C3_1(inputs)
        conv3_2=self.C3_2(conv3_1)
        conv3=self.C3(conv3_2)
        
        pool4_1=self.S4_1(inputs)
        conv4=self.C4(pool4_1)
        return layers.Concatenate(axis=-1)([conv1,conv2,conv3,conv4])

@keras.utils.register_keras_serializable()
class Inception_v3_2(tf.keras.layers.Layer):
    def __init__(self,fliter_list,**kwargs):
        super(Inception_v3_2,self).__init__(**kwargs)
        self.fliter_list=fliter_list
        self.C1=layers.Conv2D(fliter_list[0],kernel_size=(1,1),padding="same",activation="relu")
        
        self.C2_1=layers.Conv2D(fliter_list[1],kernel_size=(1,1),padding="same",activation="relu")
        self.C2_2=layers.Conv2D(fliter_list[2],kernel_size=(1,3),padding="same",activation="relu")
        self.C2=layers.Conv2D(fliter_list[3],kernel_size=(3,1),padding="same",activation="relu")
        
        self.C3_1=layers.Conv2D(fliter_list[4],kernel_size=(1,1),padding="same",activation="relu")
        self.C3_2=layers.Conv2D(fliter_list[5],kernel_size=(1,3),padding="same",activation="relu")
        self.C3_3=layers.Conv2D(fliter_list[6],kernel_size=(3,1),padding="same",activation="relu")
        self.C3_4=layers.Conv2D(fliter_list[7],kernel_size=(1,3),padding="same",activation="relu")
        self.C3=layers.Conv2D(fliter_list[8],kernel_size=(3,1),padding="same",activation="relu")
        
        self.S4_1=layers.MaxPool2D(pool_size=3,strides=1,padding="same")
        self.C4=layers.Conv2D(fliter_list[9],kernel_size=(1,1),padding="same",activation="relu")
    def call(self,inputs):
        conv1=self.C1(inputs)
        
        conv2_1=self.C2_1(inputs)
        conv2_2=self.C2_2(conv2_1)
        conv2=self.C2(conv2_2)
        
        conv3_1=self.C3_1(inputs)
        conv3_2=self.C3_2(conv3_1)
        conv3_3=self.C3_3(conv3_2)
        conv3_4=self.C3_4(conv3_3)
        conv3=self.C3(conv3_4)
        
        pool4_1=self.S4_1(inputs)
        conv4=self.C4(pool4_1)
        return layers.Concatenate(axis=-1)([conv1,conv2,conv3,conv4])
    
@keras.utils.register_keras_serializable()
class Inception_v3_3(tf.keras.layers.Layer):
    def __init__(self,fliter_list,**kwargs):
        super(Inception_v3_3,self).__init__(**kwargs)
        self.fliter_list=fliter_list
        self.C1=layers.Conv2D(fliter_list[0],kernel_size=(1,1),padding="same",activation="relu")
        
        self.C2_1=layers.Conv2D(fliter_list[1],kernel_size=(1,1),padding="same",activation="relu")
        self.C2_2=layers.Conv2D(fliter_list[2],kernel_size=(1,3),padding="same",activation="relu")
        self.C2_3=layers.Conv2D(fliter_list[3],kernel_size=(3,1),padding="same",activation="relu")
        
        self.C3_1=layers.Conv2D(fliter_list[4],kernel_size=(1,1),padding="same",activation="relu")
        self.C3_2=layers.Conv2D(fliter_list[5],kernel_size=(3,3),padding="same",activation="relu")
        self.C3_3=layers.Conv2D(fliter_list[6],kernel_size=(1,3),padding="same",activation="relu")
        self.C3_4=layers.Conv2D(fliter_list[7],kernel_size=(3,1),padding="same",activation="relu")
        
        self.S4_1=layers.MaxPool2D(pool_size=3,strides=1,padding="same")
        self.C4=layers.Conv2D(fliter_list[8],kernel_size=(1,1),padding="same",activation="relu")
    def call(self,inputs):
        conv1=self.C1(inputs)
        
        conv2_1=self.C2_1(inputs)
        conv2_2=self.C2_2(conv2_1)
        conv2_3=self.C2_3(conv2_1)
        
        conv3_1=self.C3_1(inputs)
        conv3_2=self.C3_2(conv3_1)
        conv3_3=self.C3_3(conv3_2)
        conv3_4=self.C3_4(conv3_2)
     
        pool4_1=self.S4_1(inputs)
        conv4=self.C4(pool4_1)
        return layers.Concatenate(axis=-1)([conv1,conv2_2,conv2_3,conv3_3,conv3_4,conv4])
